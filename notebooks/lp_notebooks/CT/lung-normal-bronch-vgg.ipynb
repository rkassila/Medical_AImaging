# %% [markdown]
# # 1V1 VGG - CT/Lung/ Norm VS Bronch(L.P)

# %%
import sys
sys.path.append('../..')

# %%
url_normal = '../../data/CT/Lung/normal/'
url_bronch = '../../data/CT/Lung/Bronchiectasis/'

# %%
from louis_directory.auto_vgg16 import AutoVgg16

# %%
train = AutoVgg16(url_normal, url_bronch, limit=300)
# Out:
# Epoch 1/5
# 5/5 [==============================] - 98s 21s/step - loss: 69.0617 - binary_accuracy: 0.6313 - recall: 0.6904 - val_loss: 18.5843 - val_binary_accuracy: 0.6687 - val_recall: 0.2838
# Epoch 2/5
# 5/5 [==============================] - 76s 15s/step - loss: 9.2575 - binary_accuracy: 0.8438 - recall: 0.7616 - val_loss: 11.2380 - val_binary_accuracy: 0.9375 - val_recall: 1.0000
# Epoch 3/5
# 5/5 [==============================] - 54s 11s/step - loss: 10.0747 - binary_accuracy: 0.9344 - recall: 0.9969 - val_loss: 10.0115 - val_binary_accuracy: 0.9438 - val_recall: 1.0000
# Epoch 4/5
# 5/5 [==============================] - 66s 14s/step - loss: 5.4676 - binary_accuracy: 0.9484 - recall: 0.9721 - val_loss: 4.1546 - val_binary_accuracy: 0.9563 - val_recall: 0.9730
# Epoch 5/5
# 5/5 [==============================] - 64s 13s/step - loss: 2.4106 - binary_accuracy: 0.9484 - recall: 0.9350 - val_loss: 2.8865 - val_binary_accuracy: 0.9187 - val_recall: 0.8649

# %%
train.plot_loss_accuracy()

# %%
train.evaluate_accuracy()
# Out:
# 7/7 [==============================] - 13s 2s/step - loss: 3.7481 - binary_accuracy: 0.9050 - recall: 0.8738
# 'accuracy:0.9049999713897705, recall:0.8737863898277283'
