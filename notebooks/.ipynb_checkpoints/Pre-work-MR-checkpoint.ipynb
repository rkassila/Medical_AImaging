# %% [markdown]
# <font size="12">Exploring the datasets</font>

# %% [markdown]
# # Setting up

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import pathlib
import keras
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Importing data

# %%
url_normal = '../data/MR/Lung/normal/'

url_airspace = '../data/CT/Lung/Airspace_opacity/'
url_bronch = '../data/CT/Lung/Bronchiectasis/'
url_inter = '../data/CT/Lung/interstitial_lung_disease/'
url_nodule = '../data/CT/Lung/Nodule/'
url_parenchyma = '../data/CT/Lung/Parenchyma_destruction/'

# %%
limit = 100

# %%
images_normal = [cv2.imread(file) for file in glob.glob(url_normal+"*.png")]

# %%
images_airspace = [cv2.imread(file) for file in glob.glob(url_airspace+"*.png")][:limite]
images_bronch = [cv2.imread(file) for file in glob.glob(url_bronch+"*.png")][:limite]
images_inter = [cv2.imread(file) for file in glob.glob(url_inter+"*.png")][:limite]
images_nodule = [cv2.imread(file) for file in glob.glob(url_nodule+"*.png")][:limite]
images_parenchyma = [cv2.imread(file) for file in glob.glob(url_parenchyma+"*.png")][:limite]

# %%
#images_nodule = [cv2.imread(file) for file in glob.glob(url_nodule + "*.png")]
labels_airspace = [2] * len(images_nodule)
labels_bronch = [3] * len(images_nodule)
labels_inter = [4] * len(images_nodule)
labels_nodule = [1] * len(images_nodule)
labels_parenchyma = [5] * len(images_nodule)

#images_normal = [cv2.imread(file) for file in glob.glob(url_normal + "*.png")]
labels_normal = [0] * len(images_normal)

# %% [markdown]
# ## Checking data

# %%
normal_count = len(images_normal)
normal_count
# Out:
# 320

# %%
img = np.asarray(images_nodule[0])
imgplot = plt.imshow(img)

# %% [markdown]
# # Model definition

# %%
def initialize_model():

    model = models.Sequential()

    model.add(layers.Conv2D(16, (4,4), activation="relu", input_shape=(224, 224, 3)))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    model.add(layers.Conv2D(32, (3,3), activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    model.add(layers.Conv2D(64, (3,3), activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    model.add(layers.Conv2D(64, (2,2), activation="relu"))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    model.add(layers.Flatten())
    
    model.add(layers.Dense(32, activation='relu'))

    model.add(layers.Dense(6, activation='softmax'))
    
    ### Model compilation
    model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
       
    
    return model

# %% [markdown]
# # Creating X and y for training and testing

# %%
X = np.concatenate((images_airspace, images_bronch, images_inter, images_nodule, images_parenchyma, images_normal), axis=0)
y = np.concatenate((labels_airspace, labels_bronch, labels_inter, labels_nodule, labels_parenchyma, labels_normal), axis=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (656, 224, 224, 3)

# %%
y_train.shape
# Out:
# (656,)

# %% [markdown]
# # Training the model

# %%
model = initialize_model()

# %%
es = EarlyStopping(patience = 20, restore_best_weights=False)

history = model.fit(X_train, y_train, 
          epochs=20,
          batch_size=64,
          validation_split = 0.2,
          callbacks=[es],
          verbose=1)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x259642170> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x259642170>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x259642170> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x259642170>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 9/9 [==============================] - ETA: 0s - loss: 45.6273 - accuracy: 0.2691WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2597115a0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x2597115a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2597115a0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x2597115a0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 9/9 [==============================] - 10s 976ms/step - loss: 45.6273 - accuracy: 0.2691 - val_loss: 2.2565 - val_accuracy: 0.5076
# Epoch 2/20
# 9/9 [==============================] - 9s 1s/step - loss: 2.1339 - accuracy: 0.3416 - val_loss: 1.4601 - val_accuracy: 0.4924
# Epoch 3/20
# 9/9 [==============================] - 9s 1s/step - loss: 1.5680 - accuracy: 0.4179 - val_loss: 1.2952 - val_accuracy: 0.4621
# Epoch 4/20
# 9/9 [==============================] - 9s 1s/step - loss: 1.4340 - accuracy: 0.4676 - val_loss: 1.3672 - val_accuracy: 0.4394
# Epoch 5/20
# 9/9 [==============================] - 9s 1s/step - loss: 1.4245 - accuracy: 0.4523 - val_loss: 1.2064 - val_accuracy: 0.5076
# Epoch 6/20
# 9/9 [==============================] - 9s 1s/step - loss: 1.3408 - accuracy: 0.5057 - val_loss: 1.2094 - val_accuracy: 0.4848
# Epoch 7/20
# 9/9 [==============================] - 9s 1s/step - loss: 1.2749 - accuracy: 0.5172 - val_loss: 1.1775 - val_accuracy: 0.5152
# Epoch 8/20
# 9/9 [==============================] - 9s 1s/step - loss: 1.2238 - accuracy: 0.5305 - val_loss: 1.2141 - val_accuracy: 0.5000
# Epoch 9/20
# 9/9 [==============================] - 9s 995ms/step - loss: 1.1739 - accuracy: 0.5534 - val_loss: 1.1500 - val_accuracy: 0.5530
# Epoch 10/20
# 9/9 [==============================] - 9s 971ms/step - loss: 1.1247 - accuracy: 0.5573 - val_loss: 1.1588 - val_accuracy: 0.5227
# Epoch 11/20
# 9/9 [==============================] - 9s 973ms/step - loss: 1.0430 - accuracy: 0.5897 - val_loss: 1.1800 - val_accuracy: 0.5152
# Epoch 12/20
# 9/9 [==============================] - 9s 963ms/step - loss: 1.0082 - accuracy: 0.6011 - val_loss: 1.1434 - val_accuracy: 0.5303
# Epoch 13/20
# 9/9 [==============================] - 9s 1s/step - loss: 0.9587 - accuracy: 0.6183 - val_loss: 1.1579 - val_accuracy: 0.5152
# Epoch 14/20
# 9/9 [==============================] - 9s 951ms/step - loss: 0.8947 - accuracy: 0.6393 - val_loss: 1.1702 - val_accuracy: 0.5379
# Epoch 15/20
# 9/9 [==============================] - 9s 958ms/step - loss: 0.8605 - accuracy: 0.6622 - val_loss: 1.1669 - val_accuracy: 0.5379
# Epoch 16/20
# 9/9 [==============================] - 9s 967ms/step - loss: 0.8159 - accuracy: 0.6832 - val_loss: 1.1787 - val_accuracy: 0.5379
# Epoch 17/20
# 9/9 [==============================] - 9s 950ms/step - loss: 0.7842 - accuracy: 0.6947 - val_loss: 1.1574 - val_accuracy: 0.5833
# Epoch 18/20
# 9/9 [==============================] - 9s 943ms/step - loss: 0.7378 - accuracy: 0.7424 - val_loss: 1.1772 - val_accuracy: 0.5985
# Epoch 19/20
# 9/9 [==============================] - 9s 954ms/step - loss: 0.7105 - accuracy: 0.7366 - val_loss: 1.2116 - val_accuracy: 0.5758
# Epoch 20/20
# 9/9 [==============================] - 9s 950ms/step - loss: 0.6905 - accuracy: 0.7729 - val_loss: 1.1858 - val_accuracy: 0.6136

# %% [markdown]
# # Testing the model and displaying results

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    
    # --- LOSS --- 
    
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylim((0,3))
    ax[0].legend(['Train', 'Validation'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # --- ACCURACY
    
    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])
    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Validation'], loc='best')
    ax[1].set_ylim((0,1))
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
    
    if title:
        fig.suptitle(title)

# %%
plot_loss_accuracy(history, title=None)

# %%
evaluation = model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 1s 103ms/step - loss: 1.6634 - accuracy: 0.4878

# %%
print(f'Model accuracy is {round(evaluation[1]*100,2)} %')
# Out:
# Model accuracy is 48.78 %
