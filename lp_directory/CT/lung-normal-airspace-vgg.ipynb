# %% [markdown]
# # 1V1 VGG - CT/Lung/ Norm VS Airspace(L.P)

# %%
import sys
sys.path.append('../..')

# %%
url_normal = '../../data/CT/Lung/normal/'
url_airspace = '../../data/CT/Lung/Airspace_opacity/'

# %%
from louis_directory.auto_vgg16 import AutoVgg16

# %%
train = AutoVgg16(url_normal, url_airspace, limit=500)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 56s 6s/step - loss: 67.9367 - binary_accuracy: 0.5141 - recall: 0.3540 - val_loss: 1.7842 - val_binary_accuracy: 0.7250 - val_recall: 0.8529
# Epoch 2/10
# 10/10 [==============================] - 62s 6s/step - loss: 2.3835 - binary_accuracy: 0.6031 - recall: 0.9845 - val_loss: 0.9316 - val_binary_accuracy: 0.7750 - val_recall: 0.8529
# Epoch 3/10
# 10/10 [==============================] - 67s 7s/step - loss: 0.6365 - binary_accuracy: 0.7063 - recall: 0.4876 - val_loss: 0.6639 - val_binary_accuracy: 0.6250 - val_recall: 0.1471
# Epoch 4/10
# 10/10 [==============================] - 66s 7s/step - loss: 0.6054 - binary_accuracy: 0.6984 - recall: 0.4348 - val_loss: 0.6066 - val_binary_accuracy: 0.7625 - val_recall: 0.7206
# Epoch 5/10
# 10/10 [==============================] - 53s 5s/step - loss: 0.5435 - binary_accuracy: 0.8109 - recall: 0.8851 - val_loss: 0.5838 - val_binary_accuracy: 0.7937 - val_recall: 0.8824
# Epoch 6/10
# 10/10 [==============================] - 54s 6s/step - loss: 0.4505 - binary_accuracy: 0.8641 - recall: 0.9193 - val_loss: 0.5260 - val_binary_accuracy: 0.8125 - val_recall: 0.9118
# Epoch 7/10
# 10/10 [==============================] - 54s 6s/step - loss: 0.3864 - binary_accuracy: 0.8703 - recall: 0.9317 - val_loss: 0.5281 - val_binary_accuracy: 0.7625 - val_recall: 0.9118
# Epoch 8/10
# 10/10 [==============================] - 54s 5s/step - loss: 0.3592 - binary_accuracy: 0.9094 - recall: 0.9410 - val_loss: 0.4972 - val_binary_accuracy: 0.7875 - val_recall: 0.8824
# Epoch 9/10
# 10/10 [==============================] - 55s 6s/step - loss: 0.3326 - binary_accuracy: 0.9016 - recall: 0.9503 - val_loss: 0.4914 - val_binary_accuracy: 0.7750 - val_recall: 0.8676
# Epoch 10/10
# 10/10 [==============================] - 54s 5s/step - loss: 0.3146 - binary_accuracy: 0.9453 - recall: 0.9503 - val_loss: 0.5200 - val_binary_accuracy: 0.7437 - val_recall: 0.8971

# %%
train.plot_loss_accuracy()

# %%
train.evaluate_accuracy()
# Out:
# 7/7 [==============================] - 14s 2s/step - loss: 0.4673 - binary_accuracy: 0.7800 - recall: 0.9182
# 'accuracy:0.7799999713897705, recall:0.918181836605072'
