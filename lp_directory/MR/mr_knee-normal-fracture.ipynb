# %% [markdown]
# # 1V1 - MR/knee/ Norm VS Fracture(L.P)

# %%
import sys
sys.path.append('../..')

# %%
from louis_directory.auto_trainer import AutoTrainer

# %%
url_normal = '../../data/MR/knee/normal/'
url_fracture = '../../data/MR/knee/fracture/'

# %%
train = AutoTrainer(url_normal, url_fracture, limit=200)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 641ms/step - loss: 27.1015 - binary_accuracy: 0.4688 - recall: 0.6617 - val_loss: 24.2754 - val_binary_accuracy: 0.4375 - val_recall: 1.0000
# Epoch 2/100
# 2/2 [==============================] - 1s 586ms/step - loss: 13.6152 - binary_accuracy: 0.5625 - recall: 0.6015 - val_loss: 6.9898 - val_binary_accuracy: 0.5469 - val_recall: 0.0357
# Epoch 3/100
# 2/2 [==============================] - 1s 551ms/step - loss: 6.3448 - binary_accuracy: 0.5859 - recall: 0.2632 - val_loss: 2.4349 - val_binary_accuracy: 0.6875 - val_recall: 0.8214
# Epoch 4/100
# 2/2 [==============================] - 1s 592ms/step - loss: 2.7960 - binary_accuracy: 0.6602 - recall: 0.8496 - val_loss: 3.9387 - val_binary_accuracy: 0.5781 - val_recall: 1.0000
# Epoch 5/100
# 2/2 [==============================] - 1s 559ms/step - loss: 2.9548 - binary_accuracy: 0.6406 - recall: 0.9549 - val_loss: 2.7342 - val_binary_accuracy: 0.5781 - val_recall: 1.0000
# ...

# %%
train.plot_loss_accuracy()

# %%
train.evaluate_accuracy()
# Out:
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6753 - binary_accuracy: 0.6250 - recall: 0.6923
# 'accuracy:0.625, recall:0.692307710647583'
