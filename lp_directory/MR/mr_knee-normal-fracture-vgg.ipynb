# %% [markdown]
# # 1V1 VGG - CT/Lung/ Norm VS Bronch(L.P)

# %%
import keras
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import BinaryAccuracy, Recall
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split
import sys

# %%
url_normal = '../data/MR/knee/normal/'
url_fracture = '../data/MR/knee/fracture/'

# %%
sys.path.append('..')

# %%
from louis_directory.auto_vgg16 import AutoVgg16

# %%
train = AutoVgg16(url_normal, url_fracture, limit=300)
# Out:
# Epoch 1/5
# 3/3 [==============================] - 34s 13s/step - loss: 101.8077 - binary_accuracy: 0.5417 - recall: 0.7552 - val_loss: 25.5532 - val_binary_accuracy: 0.6042 - val_recall: 0.8824
# Epoch 2/5
# 3/3 [==============================] - 42s 14s/step - loss: 12.6012 - binary_accuracy: 0.6667 - recall: 0.5885 - val_loss: 15.2884 - val_binary_accuracy: 0.4688 - val_recall: 0.0000e+00
# Epoch 3/5
# 3/3 [==============================] - 45s 17s/step - loss: 7.8241 - binary_accuracy: 0.5885 - recall: 0.1823 - val_loss: 2.8921 - val_binary_accuracy: 0.7604 - val_recall: 0.7843
# Epoch 4/5
# 3/3 [==============================] - 58s 22s/step - loss: 2.2350 - binary_accuracy: 0.7734 - recall: 0.8438 - val_loss: 3.7214 - val_binary_accuracy: 0.6458 - val_recall: 0.9020
# Epoch 5/5
# 3/3 [==============================] - 59s 22s/step - loss: 2.6176 - binary_accuracy: 0.7188 - recall: 0.9688 - val_loss: 2.6171 - val_binary_accuracy: 0.6875 - val_recall: 1.0000

# %%
train.plot_loss_accuracy()

# %%
train.evaluate_accuracy()
# Out:
# 4/4 [==============================] - 15s 4s/step - loss: 3.3926 - binary_accuracy: 0.6667 - recall: 0.9474
# 'accuracy:0.6666666865348816, recall:0.9473684430122375'
